# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Импортируем датасет, поулченный ранее

# %%
df_tracks = pd.read_csv('/tracks_spotify.csv')
df_tracks.head()
# Out:
#    Unnamed: 0                                name  duration  explicit  \
# 0           0         Born With A Beer In My Hand  188523.0       0.0
# 1           1                          Last Night  163854.0       1.0
# 2           2                   Everything I Love  187047.0       0.0
# 3           3  Man Made A Bar (feat. Eric Church)  191231.0       0.0
# 4           4                    Devil Don’t Know  205182.0       0.0
#
#    track number  countries  popularity  danceability  energy  key  loudness  \
# 0           1.0      183.0        77.0         0.531   0.810  0.0    -5.475
# 1           2.0      183.0        89.0         0.492   0.675  6.0    -5.456
# 2           3.0      183.0        80.0         0.568   0.841  8.0    -3.802
# 3           4.0      183.0        81.0         0.498   0.764  4.0    -5.006
# 4           5.0      183.0        76.0         0.530   0.664  0.0    -5.648
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0401       0.05020          0.000039    0.3570    0.608
# 1   1.0       0.0389       0.46700          0.000000    0.1420    0.478
# 2   1.0       0.0261       0.00514          0.000503    0.1470    0.668
# 3   1.0       0.0309       0.12300          0.000031    0.1190    0.489
# 4   1.0       0.0272       0.37700          0.000038    0.0937    0.323
#
#      tempo
# 0  148.026
# 1  203.759
# 2  103.983
# 3  147.984
# 4  125.002

# %% [markdown]
# Категориальных переменных в датасете нет, это хорошо, но часть признаков перед EDA предобработаем

# %%
df_tracks['explicit'] = (df_tracks['explicit'] == True)*1 #переводим в бинарную переменную

# %%
df_tracks.drop('Unnamed: 0', axis = 1, inplace = True) #избавляемся от индексов

# %%
df_tracks['duration'] = df_tracks['duration']//1000 #переводим миллисекунды в секунды

# %% [markdown]
# В тетради Parser мы проверили, есть ли пропуски в таблице, поэтому на этом этапе она уже очищена от пустот.
#
# Popularity - целевая переменная, которую мы будем потом пытаться предсказать, так что логично смотреть на визуализации с ней в первую очередь.
#
# Сначала посмотрим на распределение песен по поулярности:

# %%
sns.histplot(df_tracks.popularity)
plt.title('распредление песен по популярности');

# %% [markdown]
# Теперь посмотрим на зависимость популярности от разных параметров:

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'duration',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
)
plt.title('зависимость популярности от длительности песни');

# %% [markdown]
# Как видно из графика, есть выбросы, но так как в основном песни длятся 2-4 минуты, то проследить связь на данном графике проблематично

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'duration',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
)
plt.xlim(0,400)
plt.title('зависимость популярности от длительности песни');

# %% [markdown]
# Если же смотреть рассеивание песен, длительностью до 7 минут, то можно удотовериться, что связи между длительностью песни и ее популярностью нет. В то же время можно заметить, что с ростом популярности, растет и количество explicit песен (эту гипотезу мы проверим).

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'instrumentalness',
    y = 'popularity',
    hue = 'mode',
    palette = ['green','red']
)
plt.ylim(40,100)
plt.xlim(0.0, 0.2)
plt.title('зависимость Popularity от instrumentalness');

# %% [markdown]
# Из диаграммы видно, что подавляющее большинство песен не являются инструментальными, а выделить зависимость в данных по данному признаку невозможно. Поэтому данный признак можно не учитывать, так как он незначителен.

# %%
df_tracks.drop('instrumentalness', axis = 1, inplace = True)

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(
    data = df_tracks,
    x = 'valence',
    y = 'danceability',
    hue = 'explicit',
    palette = ['green','red']
)
plt.title('зависимость танцевальности песни от ее позитивности');

# %% [markdown]
# Как можно заметить, есть определенная зависимость между Danceability и Valence. Объединю данные признаки в один (перемножу их) и откину изначальные признаки.

# %%
df_tracks['dance-valence'] = df_tracks['danceability']*df_tracks['valence']
df_tracks = df_tracks.drop(['danceability', 'valence'], axis = 1)

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(
    data = df_tracks,
    x = 'dance-valence',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
);

# %% [markdown]
# Рассмотрим признак Countries:

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'countries',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
);

# %% [markdown]
# Зависимость популярности от страны не значима, так что избавимся от нее.

# %%
df_tracks.drop('countries', axis = 1, inplace = True)

# %% [markdown]
# Далее посмотрим на диаграммы рассеивания по разным признакам и будем так же отбрасывать незначимые признаки.

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'mode',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
);

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'key',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
);

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'liveness',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
);

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(
    data = df_tracks,
    x = 'acousticness',
    y = 'popularity',
    hue = 'explicit',
    palette = ['green','red']
);

# %% [markdown]
# По приведенным выше графикам видно, что признаки не значимы. Отброшу их.

# %%
df_tracks.drop(['acousticness','liveness','key','mode'],axis = 1, inplace = True)

# %% [markdown]
# Создадим новый признак - индикатор того, исполняется ли трек несколькими артистами или нет.

# %%
feature = []
for item in df_tracks.name.values: 
  if 'feat' in item.lower(): feature.append(1)
  else: feature.append(0)
df_tracks['feat'] = feature

# %% [markdown]
# Итоговый датасет будет иметь вид:

# %%
df_tracks
# Out:
#                                                    name  duration  explicit  \
# 0                           Born With A Beer In My Hand     188.0         0
# 1                                            Last Night     163.0         1
# 2                                     Everything I Love     187.0         0
# 3                    Man Made A Bar (feat. Eric Church)     191.0         0
# 4                                      Devil Don’t Know     205.0         0
# ...                                                 ...       ...       ...
# 3240  I Bet You Think About Me (feat. Chris Stapleto...     285.0         1
# 3241  Forever Winter (Taylor's Version) (From The Va...     263.0         0
# 3242  Run (feat. Ed Sheeran) (Taylor’s Version) (Fro...     240.0         0
# 3243  The Very First Night (Taylor's Version) (From ...     200.0         0
# 3244  All Too Well (10 Minute Version) (Taylor's Ver...     613.0         1
#
#       track number  popularity  energy  loudness  speechiness    tempo  \
# 0              1.0        77.0   0.810    -5.475       0.0401  148.026
# 1              2.0        89.0   0.675    -5.456       0.0389  203.759
# 2              3.0        80.0   0.841    -3.802       0.0261  103.983
# 3              4.0        81.0   0.764    -5.006       0.0309  147.984
# 4              5.0        76.0   0.664    -5.648       0.0272  125.002
# ...            ...         ...     ...       ...          ...      ...
# 3240          26.0        77.0   0.715    -4.516       0.0495  149.654
# 3241          27.0        69.0   0.552    -5.828       0.0310  116.012
# 3242          28.0        71.0   0.488    -6.918       0.0293  125.039
# 3243          29.0        75.0   0.733    -5.025       0.0281  121.009
# 3244          30.0        85.0   0.518    -8.771       0.0303   93.023
#
#       dance-valence  feat
# 0          0.322848     0
# 1          0.235176     0
# 2          0.379424     0
# 3          0.243522     1
# 4          0.171190     0
# ...             ...   ...
# 3240       0.184943     1
# 3241       0.250510     0
# 3242       0.270230     1
# 3243       0.393918     0
# 3244       0.129355     0
#
# [3245 rows x 11 columns]

# %% [markdown]
# Давайте посмотрим на корреляцию между признаками:

# %%
sns.heatmap(df_tracks.corr(), 
            cmap = 'RdBu',
            linewidths = 0.1,
)
# Out:
# <ipython-input-201-8c8274f76094>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_tracks.corr(),
# <Axes: >

# %% [markdown]
# Как показывает heatmap, высокой корреляцией также обладают признаки loudness и energy. Объединим их в один:

# %%
df_tracks['loud-energy'] = df_tracks.loudness * df_tracks.energy
df_tracks.drop(['loudness', 'energy'], axis = 1, inplace = True)

# %%
df_tracks.to_csv('df_tracks.csv')
